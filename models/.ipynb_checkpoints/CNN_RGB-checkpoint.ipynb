# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tqdm import tqdm
import tensorflow.keras.utils as image
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
import cv2

# Load input data
csv_file = r'C:\\Users\\User\\Documents\\Year 4\\ml_mep2\\image\\image_dataset\\image_feature.csv'
df = pd.read_csv(csv_file)

df_image = []
image_width = 60
image_height = 60
for i in tqdm(range(df.shape[0])):
    img = cv2.imread(r'C:\\Users\\User\\Documents\\Year 4\\ml_mep2\\image\\image_dataset\\'+df['img_id'][i]+'.jpg')
    img = cv2.resize(img, (image_width, image_height))
    left = int(image_width*0.4)
    top = int(image_height*0.4)
    right = int(image_width*0.6)
    bottom = int(image_height*0.6)
    img = img[left:right, top:bottom]
    img1 = image.img_to_array(img)
    df_image.append(img1)

num_channel = 3 #RGB
image_width = int(right-left)
image_height = int(bottom-top)
X = np.array(df_image)
X_col = len(df.index)
X = X.reshape(X_col, image_width, image_height, num_channel)
X /= 255

y = np.array(df['absorbance'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)


# Define model architecture
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=(X_train.shape[1:])))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=128, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# Train model
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[es])

# Evaluate model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('MSE:', test_loss)
print('MAE:', test_acc)

# Get the training and validation loss values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Get the number of epochs
epochs = range(1, len(train_loss) + 1)

# Plot the training and validation loss
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 226/226 [00:16<00:00, 13.99it/s]
# Epoch 1/100
# 6/6 [==============================] - 0s 24ms/step - loss: 8.3902 - mean_absolute_error: 1.9600 - val_loss: 3.4354 - val_mean_absolute_error: 1.5490
# Epoch 2/100
# 6/6 [==============================] - 0s 8ms/step - loss: 6.7076 - mean_absolute_error: 1.6549 - val_loss: 1.9481 - val_mean_absolute_error: 0.9343
# Epoch 3/100
# 6/6 [==============================] - 0s 8ms/step - loss: 5.2816 - mean_absolute_error: 1.4245 - val_loss: 0.8552 - val_mean_absolute_error: 0.5334
# Epoch 4/100
# 6/6 [==============================] - 0s 8ms/step - loss: 3.6213 - mean_absolute_error: 0.9361 - val_loss: 1.3769 - val_mean_absolute_error: 0.8146
# Epoch 5/100
# 6/6 [==============================] - 0s 8ms/step - loss: 3.0015 - mean_absolute_error: 1.0189 - val_loss: 1.5910 - val_mean_absolute_error: 0.8915
# Epoch 6/100
# 6/6 [==============================] - 0s 9ms/step - loss: 2.7263 - mean_absolute_error: 0.9439 - val_loss: 0.7369 - val_mean_absolute_error: 0.5543
# Epoch 7/100
# 6/6 [==============================] - 0s 8ms/step - loss: 2.6531 - mean_absolute_error: 0.8406 - val_loss: 0.8820 - val_mean_absolute_error: 0.7203
# Epoch 8/100
# 6/6 [==============================] - 0s 8ms/step - loss: 2.2061 - mean_absolute_error: 0.8685 - val_loss: 0.8305 - val_mean_absolute_error: 0.6475
# Epoch 9/100
# 6/6 [==============================] - 0s 9ms/step - loss: 1.8381 - mean_absolute_error: 0.8122 - val_loss: 0.6885 - val_mean_absolute_error: 0.5504
# Epoch 10/100
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4823 - mean_absolute_error: 0.6767 - val_loss: 0.2846 - val_mean_absolute_error: 0.3969
# Epoch 11/100
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1114 - mean_absolute_error: 0.5825 - val_loss: 0.2251 - val_mean_absolute_error: 0.3667
# Epoch 12/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7791 - mean_absolute_error: 0.5209 - val_loss: 0.1254 - val_mean_absolute_error: 0.2709
# Epoch 13/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6278 - mean_absolute_error: 0.4620 - val_loss: 0.1650 - val_mean_absolute_error: 0.3617
# Epoch 14/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6058 - mean_absolute_error: 0.4702 - val_loss: 0.4234 - val_mean_absolute_error: 0.5274
# Epoch 15/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5246 - mean_absolute_error: 0.5011 - val_loss: 0.1941 - val_mean_absolute_error: 0.4017
# Epoch 16/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4206 - mean_absolute_error: 0.4208 - val_loss: 0.3565 - val_mean_absolute_error: 0.5107
# Epoch 17/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4285 - mean_absolute_error: 0.4579 - val_loss: 0.2338 - val_mean_absolute_error: 0.4408
# Epoch 18/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4369 - mean_absolute_error: 0.4330 - val_loss: 0.2116 - val_mean_absolute_error: 0.3468
# Epoch 19/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4149 - mean_absolute_error: 0.3956 - val_loss: 0.0760 - val_mean_absolute_error: 0.2121
# Epoch 20/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3022 - mean_absolute_error: 0.3446 - val_loss: 0.1231 - val_mean_absolute_error: 0.2620
# Epoch 21/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2910 - mean_absolute_error: 0.3404 - val_loss: 0.0687 - val_mean_absolute_error: 0.2069
# Epoch 22/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2939 - mean_absolute_error: 0.3507 - val_loss: 0.0703 - val_mean_absolute_error: 0.2071
# Epoch 23/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2777 - mean_absolute_error: 0.3294 - val_loss: 0.0988 - val_mean_absolute_error: 0.2308
# Epoch 24/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2830 - mean_absolute_error: 0.3158 - val_loss: 0.0904 - val_mean_absolute_error: 0.2100
# Epoch 25/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4006 - mean_absolute_error: 0.3922 - val_loss: 0.0890 - val_mean_absolute_error: 0.2662
# Epoch 26/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2644 - mean_absolute_error: 0.3314 - val_loss: 0.1667 - val_mean_absolute_error: 0.2940
# Epoch 27/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4066 - mean_absolute_error: 0.4002 - val_loss: 0.1822 - val_mean_absolute_error: 0.3597
# Epoch 28/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4984 - mean_absolute_error: 0.4058 - val_loss: 0.3051 - val_mean_absolute_error: 0.4343
# Epoch 29/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3455 - mean_absolute_error: 0.4015 - val_loss: 0.1271 - val_mean_absolute_error: 0.3285
# Epoch 30/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3358 - mean_absolute_error: 0.3894 - val_loss: 0.1056 - val_mean_absolute_error: 0.2280
# Epoch 31/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2378 - mean_absolute_error: 0.2986 - val_loss: 0.0659 - val_mean_absolute_error: 0.2063
# Epoch 32/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2558 - mean_absolute_error: 0.3104 - val_loss: 0.0686 - val_mean_absolute_error: 0.2159
# Epoch 33/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2253 - mean_absolute_error: 0.2953 - val_loss: 0.0845 - val_mean_absolute_error: 0.2077
# Epoch 34/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2131 - mean_absolute_error: 0.2931 - val_loss: 0.0828 - val_mean_absolute_error: 0.2195
# Epoch 35/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2127 - mean_absolute_error: 0.2933 - val_loss: 0.0886 - val_mean_absolute_error: 0.2092
# Epoch 36/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2218 - mean_absolute_error: 0.2926 - val_loss: 0.0659 - val_mean_absolute_error: 0.2039
# Epoch 37/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2114 - mean_absolute_error: 0.2935 - val_loss: 0.0879 - val_mean_absolute_error: 0.2162
# Epoch 38/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2048 - mean_absolute_error: 0.2889 - val_loss: 0.0674 - val_mean_absolute_error: 0.1947
# Epoch 39/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2001 - mean_absolute_error: 0.2810 - val_loss: 0.0696 - val_mean_absolute_error: 0.1991
# Epoch 40/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2550 - mean_absolute_error: 0.3063 - val_loss: 0.0762 - val_mean_absolute_error: 0.2450
# Epoch 41/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2227 - mean_absolute_error: 0.3000 - val_loss: 0.1295 - val_mean_absolute_error: 0.2717
# Epoch 42/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2113 - mean_absolute_error: 0.2940 - val_loss: 0.0758 - val_mean_absolute_error: 0.2118
# Epoch 43/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1812 - mean_absolute_error: 0.2773 - val_loss: 0.1054 - val_mean_absolute_error: 0.2234
# Epoch 44/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1768 - mean_absolute_error: 0.2711 - val_loss: 0.0577 - val_mean_absolute_error: 0.1890
# Epoch 45/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1925 - mean_absolute_error: 0.2787 - val_loss: 0.1231 - val_mean_absolute_error: 0.2351
# Epoch 46/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1877 - mean_absolute_error: 0.2992 - val_loss: 0.0619 - val_mean_absolute_error: 0.2041
# Epoch 47/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1858 - mean_absolute_error: 0.2806 - val_loss: 0.0773 - val_mean_absolute_error: 0.2020
# Epoch 48/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1702 - mean_absolute_error: 0.2830 - val_loss: 0.0853 - val_mean_absolute_error: 0.2276
# Epoch 49/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1624 - mean_absolute_error: 0.2623 - val_loss: 0.0615 - val_mean_absolute_error: 0.1852
# Epoch 50/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1742 - mean_absolute_error: 0.2693 - val_loss: 0.0629 - val_mean_absolute_error: 0.1963
# Epoch 51/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1651 - mean_absolute_error: 0.2714 - val_loss: 0.0645 - val_mean_absolute_error: 0.1958
# Epoch 52/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1654 - mean_absolute_error: 0.2575 - val_loss: 0.0860 - val_mean_absolute_error: 0.2035
# Epoch 53/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2001 - mean_absolute_error: 0.2711 - val_loss: 0.1139 - val_mean_absolute_error: 0.2313
# Epoch 54/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1555 - mean_absolute_error: 0.2676 - val_loss: 0.0731 - val_mean_absolute_error: 0.1959
# Epoch 55/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1491 - mean_absolute_error: 0.2635 - val_loss: 0.0662 - val_mean_absolute_error: 0.1958
# Epoch 56/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1482 - mean_absolute_error: 0.2604 - val_loss: 0.0770 - val_mean_absolute_error: 0.2009
# Epoch 57/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1576 - mean_absolute_error: 0.2772 - val_loss: 0.0612 - val_mean_absolute_error: 0.2069
# Epoch 58/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1680 - mean_absolute_error: 0.2696 - val_loss: 0.2045 - val_mean_absolute_error: 0.3310
# Epoch 59/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1622 - mean_absolute_error: 0.2884 - val_loss: 0.0932 - val_mean_absolute_error: 0.2673
# Epoch 60/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1925 - mean_absolute_error: 0.2803 - val_loss: 0.1878 - val_mean_absolute_error: 0.2968
# Epoch 61/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2110 - mean_absolute_error: 0.3064 - val_loss: 0.1147 - val_mean_absolute_error: 0.2312
# Epoch 62/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1644 - mean_absolute_error: 0.2863 - val_loss: 0.0648 - val_mean_absolute_error: 0.2210
# Epoch 63/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1477 - mean_absolute_error: 0.2619 - val_loss: 0.1673 - val_mean_absolute_error: 0.2769
# Epoch 64/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1641 - mean_absolute_error: 0.2673 - val_loss: 0.0593 - val_mean_absolute_error: 0.2066
# Epoch 65/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1248 - mean_absolute_error: 0.2268 - val_loss: 0.1737 - val_mean_absolute_error: 0.2688
# Epoch 66/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1782 - mean_absolute_error: 0.2850 - val_loss: 0.0570 - val_mean_absolute_error: 0.1871
# Epoch 67/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1960 - mean_absolute_error: 0.3143 - val_loss: 0.0749 - val_mean_absolute_error: 0.2461
# Epoch 68/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1586 - mean_absolute_error: 0.2807 - val_loss: 0.2024 - val_mean_absolute_error: 0.3296
# Epoch 69/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1460 - mean_absolute_error: 0.2829 - val_loss: 0.0849 - val_mean_absolute_error: 0.2632
# Epoch 70/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1286 - mean_absolute_error: 0.2561 - val_loss: 0.2012 - val_mean_absolute_error: 0.3091
# Epoch 71/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1502 - mean_absolute_error: 0.2779 - val_loss: 0.0735 - val_mean_absolute_error: 0.2320
# Epoch 72/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1396 - mean_absolute_error: 0.2707 - val_loss: 0.1062 - val_mean_absolute_error: 0.2253
# Epoch 73/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1262 - mean_absolute_error: 0.2595 - val_loss: 0.1058 - val_mean_absolute_error: 0.2262
# Epoch 74/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1681 - mean_absolute_error: 0.2845 - val_loss: 0.0719 - val_mean_absolute_error: 0.2387
# Epoch 75/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1766 - mean_absolute_error: 0.2960 - val_loss: 0.1952 - val_mean_absolute_error: 0.3306
# Epoch 76/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1428 - mean_absolute_error: 0.2727 - val_loss: 0.0634 - val_mean_absolute_error: 0.2110
# Epoch 77/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0989 - mean_absolute_error: 0.2229 - val_loss: 0.1396 - val_mean_absolute_error: 0.2621
# Epoch 78/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1110 - mean_absolute_error: 0.2395 - val_loss: 0.0636 - val_mean_absolute_error: 0.2194
# Epoch 79/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1386 - mean_absolute_error: 0.2603 - val_loss: 0.0573 - val_mean_absolute_error: 0.1868
# Epoch 80/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1187 - mean_absolute_error: 0.2326 - val_loss: 0.1727 - val_mean_absolute_error: 0.2661
# Epoch 81/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1258 - mean_absolute_error: 0.2401 - val_loss: 0.0527 - val_mean_absolute_error: 0.1892
# Epoch 82/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0987 - mean_absolute_error: 0.2246 - val_loss: 0.0758 - val_mean_absolute_error: 0.1931
# Epoch 83/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0934 - mean_absolute_error: 0.2212 - val_loss: 0.0707 - val_mean_absolute_error: 0.1959
# Epoch 84/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0936 - mean_absolute_error: 0.2203 - val_loss: 0.0531 - val_mean_absolute_error: 0.1857
# Epoch 85/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0939 - mean_absolute_error: 0.2119 - val_loss: 0.1448 - val_mean_absolute_error: 0.2560
# Epoch 86/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1001 - mean_absolute_error: 0.2150 - val_loss: 0.0560 - val_mean_absolute_error: 0.1946
# Epoch 87/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0870 - mean_absolute_error: 0.2063 - val_loss: 0.1191 - val_mean_absolute_error: 0.2409
# Epoch 88/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0969 - mean_absolute_error: 0.2246 - val_loss: 0.0636 - val_mean_absolute_error: 0.1934
# Epoch 89/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1172 - mean_absolute_error: 0.2419 - val_loss: 0.0550 - val_mean_absolute_error: 0.2008
# Epoch 90/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1046 - mean_absolute_error: 0.2261 - val_loss: 0.0870 - val_mean_absolute_error: 0.2041
# Epoch 91/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0853 - mean_absolute_error: 0.2078 - val_loss: 0.0702 - val_mean_absolute_error: 0.1917
# Epoch 92/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0893 - mean_absolute_error: 0.2222 - val_loss: 0.0538 - val_mean_absolute_error: 0.1933
# Epoch 93/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1051 - mean_absolute_error: 0.2232 - val_loss: 0.0672 - val_mean_absolute_error: 0.1899
# Epoch 94/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1087 - mean_absolute_error: 0.2265 - val_loss: 0.1129 - val_mean_absolute_error: 0.2409
# Epoch 95/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0931 - mean_absolute_error: 0.2170 - val_loss: 0.0679 - val_mean_absolute_error: 0.1869
# Epoch 96/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0998 - mean_absolute_error: 0.2176 - val_loss: 0.0632 - val_mean_absolute_error: 0.1844
# Epoch 97/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0806 - mean_absolute_error: 0.1999 - val_loss: 0.0630 - val_mean_absolute_error: 0.1848
# Epoch 98/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0921 - mean_absolute_error: 0.2025 - val_loss: 0.1691 - val_mean_absolute_error: 0.2636
# Epoch 99/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0932 - mean_absolute_error: 0.2219 - val_loss: 0.0486 - val_mean_absolute_error: 0.1849
# Epoch 100/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0825 - mean_absolute_error: 0.2233 - val_loss: 0.1113 - val_mean_absolute_error: 0.2239
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1113 - mean_absolute_error: 0.2239
# MSE: 0.11127215623855591
# MAE: 0.2238733321428299
