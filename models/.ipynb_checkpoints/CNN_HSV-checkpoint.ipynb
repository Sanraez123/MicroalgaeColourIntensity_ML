# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tqdm import tqdm
import tensorflow.keras.utils as image
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from skimage import color
import cv2
# Load input data
csv_file = r'C:\\Users\\User\\Documents\\Year 4\\ml_mep2\\image\\image_dataset\\image_feature.csv'
df = pd.read_csv(csv_file)

df_image = []
image_width = 60
image_height = 60
for i in tqdm(range(df.shape[0])):
    img = cv2.imread(r'C:\\Users\\User\\Documents\\Year 4\\ml_mep2\\image\\image_dataset\\'+df['img_id'][i]+'.jpg')
    img = cv2.resize(img, (image_width, image_height))
    left = int(image_width*0.4)
    top = int(image_height*0.4)
    right = int(image_width*0.6)
    bottom = int(image_height*0.6)
    img = img[left:right, top:bottom]
    img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    img1 = image.img_to_array(img)
    df_image.append(img1)

#plt.figure()
#plt.imshow(img) 
#plt.show()  # display it

num_channel = 3 #RGB
image_width = int(right-left)
image_height = int(bottom-top)
X = np.array(df_image)
X_col = len(df.index)
X = X.reshape(X_col, image_width, image_height, num_channel)
X /= 255

y = np.array(df['absorbance'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)


# Define model architecture
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=(X_train.shape[1:])))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=128, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))

# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# Train model
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[es])

# Evaluate model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('MSE:', test_loss)
print('MAE:', test_acc)

# Get the training and validation loss values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Get the number of epochs
epochs = range(1, len(train_loss) + 1)

# Plot the training and validation loss
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 226/226 [00:16<00:00, 13.93it/s]
# Epoch 1/100
# 6/6 [==============================] - 0s 23ms/step - loss: 9.3471 - mean_absolute_error: 1.9860 - val_loss: 3.9054 - val_mean_absolute_error: 1.6593
# Epoch 2/100
# 6/6 [==============================] - 0s 9ms/step - loss: 7.1259 - mean_absolute_error: 1.8568 - val_loss: 2.3357 - val_mean_absolute_error: 1.1241
# Epoch 3/100
# 6/6 [==============================] - 0s 9ms/step - loss: 5.1776 - mean_absolute_error: 1.2994 - val_loss: 0.8125 - val_mean_absolute_error: 0.5405
# Epoch 4/100
# 6/6 [==============================] - 0s 8ms/step - loss: 3.2476 - mean_absolute_error: 0.9464 - val_loss: 1.5158 - val_mean_absolute_error: 0.9718
# Epoch 5/100
# 6/6 [==============================] - 0s 8ms/step - loss: 2.7459 - mean_absolute_error: 1.0884 - val_loss: 0.7972 - val_mean_absolute_error: 0.6499
# Epoch 6/100
# 6/6 [==============================] - 0s 9ms/step - loss: 2.3505 - mean_absolute_error: 0.8847 - val_loss: 1.2387 - val_mean_absolute_error: 0.9357
# Epoch 7/100
# 6/6 [==============================] - 0s 8ms/step - loss: 2.2132 - mean_absolute_error: 0.9643 - val_loss: 0.7023 - val_mean_absolute_error: 0.6930
# Epoch 8/100
# 6/6 [==============================] - 0s 9ms/step - loss: 1.9109 - mean_absolute_error: 0.9711 - val_loss: 0.8590 - val_mean_absolute_error: 0.6830
# Epoch 9/100
# 6/6 [==============================] - 0s 8ms/step - loss: 1.4447 - mean_absolute_error: 0.7668 - val_loss: 0.4151 - val_mean_absolute_error: 0.5623
# Epoch 10/100
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0868 - mean_absolute_error: 0.6789 - val_loss: 0.2794 - val_mean_absolute_error: 0.4471
# Epoch 11/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8050 - mean_absolute_error: 0.5702 - val_loss: 0.2326 - val_mean_absolute_error: 0.3428
# Epoch 12/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6530 - mean_absolute_error: 0.5171 - val_loss: 0.1627 - val_mean_absolute_error: 0.3250
# Epoch 13/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5600 - mean_absolute_error: 0.4684 - val_loss: 0.1792 - val_mean_absolute_error: 0.3233
# Epoch 14/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5266 - mean_absolute_error: 0.4837 - val_loss: 0.1723 - val_mean_absolute_error: 0.3589
# Epoch 15/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4875 - mean_absolute_error: 0.4171 - val_loss: 0.1585 - val_mean_absolute_error: 0.3064
# Epoch 16/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4053 - mean_absolute_error: 0.3979 - val_loss: 0.0921 - val_mean_absolute_error: 0.2480
# Epoch 17/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4335 - mean_absolute_error: 0.3910 - val_loss: 0.1148 - val_mean_absolute_error: 0.2593
# Epoch 18/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4249 - mean_absolute_error: 0.3846 - val_loss: 0.0836 - val_mean_absolute_error: 0.2214
# Epoch 19/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3559 - mean_absolute_error: 0.3517 - val_loss: 0.0901 - val_mean_absolute_error: 0.2618
# Epoch 20/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4203 - mean_absolute_error: 0.3706 - val_loss: 0.0777 - val_mean_absolute_error: 0.2083
# Epoch 21/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4458 - mean_absolute_error: 0.3869 - val_loss: 0.3387 - val_mean_absolute_error: 0.4774
# Epoch 22/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4752 - mean_absolute_error: 0.4761 - val_loss: 0.1090 - val_mean_absolute_error: 0.2626
# Epoch 23/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3794 - mean_absolute_error: 0.4029 - val_loss: 0.0851 - val_mean_absolute_error: 0.2254
# Epoch 24/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3469 - mean_absolute_error: 0.3549 - val_loss: 0.1225 - val_mean_absolute_error: 0.2559
# Epoch 25/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3200 - mean_absolute_error: 0.3391 - val_loss: 0.0725 - val_mean_absolute_error: 0.2162
# Epoch 26/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3483 - mean_absolute_error: 0.3352 - val_loss: 0.2534 - val_mean_absolute_error: 0.3893
# Epoch 27/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4161 - mean_absolute_error: 0.4282 - val_loss: 0.1357 - val_mean_absolute_error: 0.3325
# Epoch 28/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3891 - mean_absolute_error: 0.4031 - val_loss: 0.0808 - val_mean_absolute_error: 0.2079
# Epoch 29/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3396 - mean_absolute_error: 0.3236 - val_loss: 0.1154 - val_mean_absolute_error: 0.2494
# Epoch 30/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3038 - mean_absolute_error: 0.3223 - val_loss: 0.0973 - val_mean_absolute_error: 0.2303
# Epoch 31/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2811 - mean_absolute_error: 0.3147 - val_loss: 0.0779 - val_mean_absolute_error: 0.2100
# Epoch 32/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2844 - mean_absolute_error: 0.3158 - val_loss: 0.0735 - val_mean_absolute_error: 0.1977
# Epoch 33/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2786 - mean_absolute_error: 0.3069 - val_loss: 0.0947 - val_mean_absolute_error: 0.2297
# Epoch 34/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2767 - mean_absolute_error: 0.3092 - val_loss: 0.0836 - val_mean_absolute_error: 0.2167
# Epoch 35/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2761 - mean_absolute_error: 0.3105 - val_loss: 0.0793 - val_mean_absolute_error: 0.2052
# Epoch 36/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2910 - mean_absolute_error: 0.3270 - val_loss: 0.0731 - val_mean_absolute_error: 0.2101
# Epoch 37/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2925 - mean_absolute_error: 0.3364 - val_loss: 0.0754 - val_mean_absolute_error: 0.2352
# Epoch 38/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3563 - mean_absolute_error: 0.3703 - val_loss: 0.2079 - val_mean_absolute_error: 0.3419
# Epoch 39/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2919 - mean_absolute_error: 0.3588 - val_loss: 0.0768 - val_mean_absolute_error: 0.2094
# Epoch 40/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2412 - mean_absolute_error: 0.2921 - val_loss: 0.1029 - val_mean_absolute_error: 0.2414
# Epoch 41/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2633 - mean_absolute_error: 0.3411 - val_loss: 0.0881 - val_mean_absolute_error: 0.2518
# Epoch 42/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2306 - mean_absolute_error: 0.2993 - val_loss: 0.1796 - val_mean_absolute_error: 0.3237
# Epoch 43/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2586 - mean_absolute_error: 0.3340 - val_loss: 0.1079 - val_mean_absolute_error: 0.2905
# Epoch 44/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2435 - mean_absolute_error: 0.3116 - val_loss: 0.1346 - val_mean_absolute_error: 0.2747
# Epoch 45/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2258 - mean_absolute_error: 0.2900 - val_loss: 0.0721 - val_mean_absolute_error: 0.1983
# Epoch 46/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2151 - mean_absolute_error: 0.3079 - val_loss: 0.0733 - val_mean_absolute_error: 0.2215
# Epoch 47/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2088 - mean_absolute_error: 0.2909 - val_loss: 0.1219 - val_mean_absolute_error: 0.2749
# Epoch 48/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2169 - mean_absolute_error: 0.2851 - val_loss: 0.0745 - val_mean_absolute_error: 0.2167
# Epoch 49/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2532 - mean_absolute_error: 0.3021 - val_loss: 0.0741 - val_mean_absolute_error: 0.2249
# Epoch 50/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1985 - mean_absolute_error: 0.2751 - val_loss: 0.0873 - val_mean_absolute_error: 0.2205
# Epoch 51/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1994 - mean_absolute_error: 0.2793 - val_loss: 0.0927 - val_mean_absolute_error: 0.2219
# Epoch 52/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2104 - mean_absolute_error: 0.2957 - val_loss: 0.0897 - val_mean_absolute_error: 0.2208
# Epoch 53/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2119 - mean_absolute_error: 0.3052 - val_loss: 0.0851 - val_mean_absolute_error: 0.2207
# Epoch 54/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1973 - mean_absolute_error: 0.2821 - val_loss: 0.0643 - val_mean_absolute_error: 0.1980
# Epoch 55/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1859 - mean_absolute_error: 0.2633 - val_loss: 0.1902 - val_mean_absolute_error: 0.3414
# Epoch 56/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2263 - mean_absolute_error: 0.3225 - val_loss: 0.1111 - val_mean_absolute_error: 0.2424
# Epoch 57/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2073 - mean_absolute_error: 0.3063 - val_loss: 0.0857 - val_mean_absolute_error: 0.2600
# Epoch 58/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2130 - mean_absolute_error: 0.3135 - val_loss: 0.2077 - val_mean_absolute_error: 0.3467
# Epoch 59/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1888 - mean_absolute_error: 0.3051 - val_loss: 0.0759 - val_mean_absolute_error: 0.2043
# Epoch 60/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1627 - mean_absolute_error: 0.2768 - val_loss: 0.0630 - val_mean_absolute_error: 0.1941
# Epoch 61/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1717 - mean_absolute_error: 0.2736 - val_loss: 0.1182 - val_mean_absolute_error: 0.2512
# Epoch 62/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1423 - mean_absolute_error: 0.2516 - val_loss: 0.0686 - val_mean_absolute_error: 0.1960
# Epoch 63/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1380 - mean_absolute_error: 0.2491 - val_loss: 0.0950 - val_mean_absolute_error: 0.2254
# Epoch 64/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1390 - mean_absolute_error: 0.2559 - val_loss: 0.0616 - val_mean_absolute_error: 0.2102
# Epoch 65/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1520 - mean_absolute_error: 0.2632 - val_loss: 0.0886 - val_mean_absolute_error: 0.2167
# Epoch 66/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1793 - mean_absolute_error: 0.2775 - val_loss: 0.2747 - val_mean_absolute_error: 0.3778
# Epoch 67/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2135 - mean_absolute_error: 0.3040 - val_loss: 0.0570 - val_mean_absolute_error: 0.1971
# Epoch 68/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1684 - mean_absolute_error: 0.2810 - val_loss: 0.0727 - val_mean_absolute_error: 0.2315
# Epoch 69/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1459 - mean_absolute_error: 0.2655 - val_loss: 0.1375 - val_mean_absolute_error: 0.2871
# Epoch 70/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1398 - mean_absolute_error: 0.2702 - val_loss: 0.0788 - val_mean_absolute_error: 0.2194
# Epoch 71/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1294 - mean_absolute_error: 0.2530 - val_loss: 0.0719 - val_mean_absolute_error: 0.1993
# Epoch 72/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1172 - mean_absolute_error: 0.2419 - val_loss: 0.0787 - val_mean_absolute_error: 0.2005
# Epoch 73/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1092 - mean_absolute_error: 0.2276 - val_loss: 0.0725 - val_mean_absolute_error: 0.2020
# Epoch 74/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1270 - mean_absolute_error: 0.2473 - val_loss: 0.1289 - val_mean_absolute_error: 0.2577
# Epoch 75/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1246 - mean_absolute_error: 0.2441 - val_loss: 0.0860 - val_mean_absolute_error: 0.2077
# Epoch 76/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1007 - mean_absolute_error: 0.2240 - val_loss: 0.0605 - val_mean_absolute_error: 0.1855
# Epoch 77/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0994 - mean_absolute_error: 0.2212 - val_loss: 0.0709 - val_mean_absolute_error: 0.1961
# Epoch 78/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0942 - mean_absolute_error: 0.2238 - val_loss: 0.0558 - val_mean_absolute_error: 0.1938
# Epoch 79/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0964 - mean_absolute_error: 0.2182 - val_loss: 0.0738 - val_mean_absolute_error: 0.1934
# Epoch 80/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0896 - mean_absolute_error: 0.2111 - val_loss: 0.0791 - val_mean_absolute_error: 0.2018
# Epoch 81/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0897 - mean_absolute_error: 0.2090 - val_loss: 0.1249 - val_mean_absolute_error: 0.2421
# Epoch 82/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1030 - mean_absolute_error: 0.2203 - val_loss: 0.0762 - val_mean_absolute_error: 0.1959
# Epoch 83/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0864 - mean_absolute_error: 0.2120 - val_loss: 0.0543 - val_mean_absolute_error: 0.1907
# Epoch 84/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0980 - mean_absolute_error: 0.2230 - val_loss: 0.0518 - val_mean_absolute_error: 0.1825
# Epoch 85/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0912 - mean_absolute_error: 0.2090 - val_loss: 0.1070 - val_mean_absolute_error: 0.2263
# Epoch 86/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0919 - mean_absolute_error: 0.2124 - val_loss: 0.1740 - val_mean_absolute_error: 0.3157
# Epoch 87/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1153 - mean_absolute_error: 0.2440 - val_loss: 0.1074 - val_mean_absolute_error: 0.2337
# Epoch 88/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1122 - mean_absolute_error: 0.2385 - val_loss: 0.0791 - val_mean_absolute_error: 0.1970
# Epoch 89/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0892 - mean_absolute_error: 0.2156 - val_loss: 0.0512 - val_mean_absolute_error: 0.1792
# Epoch 90/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0949 - mean_absolute_error: 0.2275 - val_loss: 0.0713 - val_mean_absolute_error: 0.2268
# Epoch 91/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1032 - mean_absolute_error: 0.2319 - val_loss: 0.0769 - val_mean_absolute_error: 0.1929
# Epoch 92/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0735 - mean_absolute_error: 0.1959 - val_loss: 0.0868 - val_mean_absolute_error: 0.2059
# Epoch 93/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0750 - mean_absolute_error: 0.1969 - val_loss: 0.0598 - val_mean_absolute_error: 0.2135
# Epoch 94/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0839 - mean_absolute_error: 0.2104 - val_loss: 0.0543 - val_mean_absolute_error: 0.1728
# Epoch 95/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1029 - mean_absolute_error: 0.2171 - val_loss: 0.0561 - val_mean_absolute_error: 0.1842
# Epoch 96/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1149 - mean_absolute_error: 0.2545 - val_loss: 0.1812 - val_mean_absolute_error: 0.3209
# Epoch 97/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0986 - mean_absolute_error: 0.2323 - val_loss: 0.2344 - val_mean_absolute_error: 0.3360
# Epoch 98/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1235 - mean_absolute_error: 0.2482 - val_loss: 0.0593 - val_mean_absolute_error: 0.2062
# Epoch 99/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1294 - mean_absolute_error: 0.2615 - val_loss: 0.0741 - val_mean_absolute_error: 0.2311
# Epoch 100/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1632 - mean_absolute_error: 0.2962 - val_loss: 0.0952 - val_mean_absolute_error: 0.2087
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0952 - mean_absolute_error: 0.2087
# MSE: 0.09521662443876266
# MAE: 0.20870155096054077
